# %% [markdown]
# Exercise #1
# Data Visualization is important in data analysis because it gives a visual insight of what the data shows.
#
# Exercise #2
#  The purpose of a line graph in data visualization to see pattern/ trends in the data. For example, population growth over the years and sales figures over the years.

# %%
import matplotlib.pyplot as plt

# Sample temperature data for a week
temperature_data = [72, 74, 76, 80, 82, 78, 75]
days = ['Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat']  # Days of the week

# Create the line plot
plt.plot(days, temperature_data)

# Label the axes
plt.xlabel('Day')
plt.ylabel('Temperature (°F)')

# Display the plot
plt.show()

# %%
#Exercise 3
sales_amount = [5000, 5500, 6200, 7000, 7500]
month = ['January', 'February', 'March', 'April', 'May']

plt.figure()
plt.plot(month, sales_amount, marker='o')

plt.ylabel("Sales Amount ($)")
plt.xlabel("Month")

plt.title("Monthly Sales")

plt.show()

# %% [markdown]
# Exercise 4: Using the dataset sales_data.csv
#
# Calculate the total quantity of products sold by the company. Identify the category that had the highest revenue and calculate how much revenue it generated. Determine the average revenue per sale in the dataset. Create a bar chart to visualize the total revenue generated in each quarter of the year (Q1, Q2, Q3, Q4).

# %%
import pandas as pd
sales_data = pd.read_csv('sales_data.csv')
sales_data

# %%
total_quantity = sales_data['quantity'].sum()
total_quantity

# %%
sales_data['revenue'] = sales_data['price'] * sales_data['quantity']
category_revenue = sales_data.groupby('category')['revenue'].sum()
category_revenue

# %%
highest_revenue_category = category_revenue.idxmax()
highest_revenue_amount = category_revenue.max()
print(f"Category with the highest revenue: {highest_revenue_category} ({highest_revenue_amount})")

# %%
avg_rev_sale = sales_data['revenue'].sum()/sales_data['quantity'].sum()
print(avg_rev_sale)

# %%
sales_data['date'] = pd.to_datetime(sales_data['date'])

sales_data['quarter'] = sales_data['date'].dt.to_period('Q')

quarterly_revenue = sales_data.groupby('quarter')['revenue'].sum()

plt.figure()
quarterly_revenue.plot(kind='bar')
plt.xlabel('Quarter')
plt.ylabel('Total Revenue')
plt.title('Total revenue generated in each quarter')
plt.xticks(rotation=0)
plt.show()

# %%
x = range(-10, 11)
y = [i**2 for i in x]
plt.figure()

plt.plot(x, y, marker='o')

plt.xlabel("x")
plt.ylabel("y")

plt.title("Number squared")

# %%
products = ['A', 'B', 'C', 'D']
sales_values = [15, 30, 45, 20]

plt.figure()
plt.bar(products, sales_values, color=['blue', 'green', 'red', 'purple'])
plt.xlabel('Products')
plt.ylabel('Sales')
plt.title('Sales Data of Four Different Products in a Week')
plt.show()

# %%
fruits = ['Apples', 'Bananas', 'Cherries', 'Dates']
percentages = [40, 30, 20, 10]
colors = ['red', 'yellow', 'pink', 'brown']

plt.figure(figsize=(9, 7))
plt.pie(percentages, labels=fruits, colors=colors)
plt.title('Favorite Fruits of a Group of People')
plt.legend(fruits)
plt.show()
