# %%
# !pip install scipy
# Out:
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy) (1.25.2)

# %% [markdown]
# 🌟 Exercise 1 : Basic Usage Of SciPy
# Instructions
# Import the SciPy library and explore its version.

# %%
import scipy as sp
import scipy
print(scipy.__version__)
# Out:
# 1.11.4

# %% [markdown]
# 🌟 Exercise 2 : Descriptive Statistics
# Instructions
# Given a sample dataset, calculate the mean, median, variance, and standard deviation using SciPy.
# Sample dataset in code:
#
#
# data = [12, 15, 13, 12, 18, 20, 22, 21]

# %%
import scipy.stats as stats
import scipy as sp
import numpy as np


data = [12, 15, 13, 12, 18, 20, 22, 21]

mean_scipy = stats.tmean(data)
median_scipy = np.median(data)  # SciPy does not have a separate median function
variance_scipy = stats.tvar(data)
std_dev_scipy = stats.tstd(data)

print(mean_scipy)
print(median_scipy)
print(variance_scipy)
print(std_dev_scipy)
# Out:
# 16.625
# 16.5
# 17.125
# 4.138236339311712

# %% [markdown]
# 🌟 Exercise 3 : Understanding Distributions
# Instructions
# Generate a normal distribution using SciPy with a mean of 50 and a standard deviation of 10. Plot this distribution.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Generate random samples from the normal distribution
data1= np.random.normal(50, 10, 1000)


mean_scipy1 = stats.tmean(data1)
median_scipy1 = np.median(data1)  # SciPy does not have a separate median function
variance_scipy1 = stats.tvar(data1)
std_dev_scipy1 = stats.tstd(data1)

print(mean_scipy1)
print(median_scipy1)
print(variance_scipy1)
print(std_dev_scipy1)


sns.histplot(data1, kde=True)  # kde=True adds a kernel density estimate curve
plt.title('Normal Distribution (Mean=50, Std Dev=10)')
plt.xlabel('x')
plt.ylabel('Frequency')
plt.show()
# Out:
# 49.723172675741424
# 49.5965318785276
# 98.36137283303779
# 9.917730225865078

# %% [markdown]
# 🌟 Exercise 4 : T-Test Application
# Instructions
# Perform a T-test on two sets of randomly generated data. Hint: Use numpy.random.normal() to generate the datasets.

# %%
import numpy as np
import scipy.stats as stats
set1 = np.random.normal(loc=50, scale=10, size=10)
set2 = np.random.normal(loc=50, scale=12, size=10)

print(set1)
print(set2)

t_test= stats.ttest_ind(set1,set2)
print(t_test)
# Out:
# [44.01330417 64.22893767 55.23237481 22.03108401 48.68756743 38.69891073
#  44.14308744 52.58095086 51.30495002 55.9532675 ]
# [67.54516677 50.52936711 64.35529528 50.57728254 49.4809     50.68731042
#  47.5597953  35.354277   73.07356698 61.18090569]
# TtestResult(statistic=-1.4403389107485605, pvalue=0.16693944250058496, df=18.0)

# %% [markdown]
# 🌟 Exercise 5 : Working With DataFrames
# Instructions
# Task: Import a dataset using Pandas and calculate descriptive statistics for a specific column using SciPy.
#
# Sample Dataset: Use any publicly available dataset (e.g., Iris dataset).
#
# Code Example:
#
#
#
# import pandas as pd
#
# df = pd.read_csv('path_to_iris_dataset.csv')

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import scipy as sp

df = pd.read_csv('Iris.csv')
df.head()

column_names= df.columns
print(column_names)


sepal_length = df['SepalLengthCm']
sepal_length_mean  = stats.tmean(sepal_length)
sepal_length_median = np.median(sepal_length)

sepal_length_variance = stats.tvar(sepal_length)
sepal_length_stdv = stats.tstd(sepal_length)


print(sepal_length_mean)
print(sepal_length_median)
print(sepal_length_variance)
print(sepal_length_stdv )
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')
# 5.843333333333334
# 5.8
# 0.6856935123042507
# 0.828066127977863

# %% [markdown]
# 🌟 Exercise 6 : Advanced Statistical Functions
# Instructions
# Task: Explore one advanced statistical function in SciPy and demonstrate its use with an example.
#
# Sample Task: Calculate kurtosis and skewness of a dataset.

# %%
#data = np.random.normal(0,1,1000)
#print(data)

skewness = stats.skew(data)
kurtosis = stats.kurtosis(data)

#using Iris DataSet
sepal_length = df['SepalLengthCm']

sepal_length_skew = stats.skew(sepal_length)
sepal_length_kurtosis = stats.kurtosis(sepal_length)

print(sepal_length_skew)
print(sepal_length_kurtosis)
# Out:
# 0.3117530585022963
# -0.5735679489249765
